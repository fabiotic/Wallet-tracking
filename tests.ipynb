# 164  0xfc5a1a6eb076a2c7ad06ed22c90d7e710e35ad0a  -8134.000000 -118561.584622
# 165  0xfc5a1a6eb076a2c7ad06ed22c90d7e710e35ad0a   8134.000000  118561.584622
#
#                                    counterparty         chain
# 0    0xae0fd6a1f53d52e320dea2607cfda7540eed0e4a      ethereum
# 1    0x6cc5f688a315f3dc28a7781717a9a798a59fda7b      ethereum
# 2    0xdfd5293d8e347dfe59e90efd55b2956a1343963d      ethereum
# 3    0x789ecc81d93decd023883a4c2d813b0d5d0f8e81      ethereum
# 4    0xc98f0e6e391a485176a238320111705f3eb82471      ethereum
# ..                                          ...           ...
# 151  0xb1125fed9606a315d8d1cd5a974b3efcba7efb06      ethereum
# 162  0xc9a952deba901d63e381e96295bce3ff30600728      ethereum
# 163  0xe93381fb4c4f14bda253907b18fad305d799241a      ethereum
# 164  0x908c4d94d34924765f1edc22a1dd098397c59dd4  arbitrum-one
# 165  0x9e51be7071f086d3a1fd5dc0016177473619b237  arbitrum-one
#
# [166 rows x 10 columns]

# %%
df1=df.groupby(['address','token', 'contract address', 'chain'])['flow','USD'].sum()
df1.reset_index(inplace=True)
df1.drop(columns='flow')
# Out:
# C:\Users\dtyq2\AppData\Local\Temp\ipykernel_20332\2830465413.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1=df.groupby(['address','token', 'contract address', 'chain'])['flow','USD'].sum()
#                                        address      token  \
# 0   0x534a0076fb7c2b1f83fa21497429ad7ad3bd7587        GMX
# 1   0x534a0076fb7c2b1f83fa21497429ad7ad3bd7587       sGMX
# 2   0x534a0076fb7c2b1f83fa21497429ad7ad3bd7587      sbGMX
# 3   0x534a0076fb7c2b1f83fa21497429ad7ad3bd7587     sbfGMX
# 4   0x8e04af7f7c76daa9ab429b1340e0327b5b835748       AAVE
# 5   0x8e04af7f7c76daa9ab429b1340e0327b5b835748       BUSD
# 6   0x8e04af7f7c76daa9ab429b1340e0327b5b835748       COMP
# 7   0x8e04af7f7c76daa9ab429b1340e0327b5b835748        CRV
# 8   0x8e04af7f7c76daa9ab429b1340e0327b5b835748        DAI
# 9   0x8e04af7f7c76daa9ab429b1340e0327b5b835748         DX
# 10  0x8e04af7f7c76daa9ab429b1340e0327b5b835748  FTX Token
# 11  0x8e04af7f7c76daa9ab429b1340e0327b5b835748       LINK
# 12  0x8e04af7f7c76daa9ab429b1340e0327b5b835748      RADAR
# 13  0x8e04af7f7c76daa9ab429b1340e0327b5b835748        SNX
# 14  0x8e04af7f7c76daa9ab429b1340e0327b5b835748        SPA
# 15  0x8e04af7f7c76daa9ab429b1340e0327b5b835748      SUSHI
# 16  0x8e04af7f7c76daa9ab429b1340e0327b5b835748        TCT
# 17  0x8e04af7f7c76daa9ab429b1340e0327b5b835748        UNI
# 18  0x8e04af7f7c76daa9ab429b1340e0327b5b835748       USDC
# 19  0x8e04af7f7c76daa9ab429b1340e0327b5b835748       USDT
# 20  0x8e04af7f7c76daa9ab429b1340e0327b5b835748        YFI
# 21  0x8e04af7f7c76daa9ab429b1340e0327b5b835748        ZKS
# 22  0x8e04af7f7c76daa9ab429b1340e0327b5b835748      pAVAX
#
#                               contract address         chain            USD
# 0   0xfc5a1a6eb076a2c7ad06ed22c90d7e710e35ad0a  arbitrum-one       0.000000
# 1   0x908c4d94d34924765f1edc22a1dd098397c59dd4  arbitrum-one       0.000000
# 2   0x4d268a7d4c16ceb5a606c173bd974984343fea13  arbitrum-one       0.000000
# 3   0xd2d1162512f927a7e282ef43a362659e4f2a728f  arbitrum-one       0.000000
# 4   0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9      ethereum      57.783849
# 5   0x4fabb145d64652a948d72533023f6e7a623c7c53      ethereum      -0.037954
# 6   0xc00e94cb662c3520282e6f5717214004a7f26888      ethereum      13.356013
# 7   0xd533a949740bb3306d119cc777fa900ba034cd52      ethereum     185.687569
# 8   0x6b175474e89094c44da98b954eedeac495271d0f      ethereum     -14.520657
# 9   0x973e52691176d36453868d9d86572788d27041a9      ethereum  801090.948606
# 10  0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9      ethereum    2326.807026
# 11  0x514910771af9ca656af840dff83e8264ecf986ca      ethereum    -744.680117
# 12  0x44709a920fccf795fbc57baa433cc3dd53c44dbe      ethereum       0.000000
# 13  0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f      ethereum      30.797536
# 14  0xb4a3b0faf0ab53df58001804dda5bfc6a3d59008      ethereum      58.227721
# 15  0x6b3595068778dd592e39a122f4f5a5cf09c90fe2      ethereum      -0.410740
# 16  0x4824a7b64e3966b0133f4f4ffb1b9d6beb75fff7      ethereum       1.405190
# 17  0x1f9840a85d5af5bf1d1762f925bdaddc4201f984      ethereum    -155.512369
# 18  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48      ethereum  237695.825220
# 19  0xdac17f958d2ee523a2206206994597c13d831ec7      ethereum -883811.554857
# 20  0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e      ethereum     457.872931
# 21  0xe4815ae53b124e7263f08dcdbbb757d41ed658c6      ethereum      94.260969
# 22  0x6ca558bd3eab53da1b25ab97916dd14bf6cfee4e     avalanche       0.045205

# %%
df1.reset_index(inplace=True)
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\dtyq2\Desktop\repos\Wallet-tracking\tests.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dtyq2/Desktop/repos/Wallet-tracking/tests.ipynb#ch0000006?line=0'>1</a> df1.reset_index(inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/dtyq2/Desktop/repos/Wallet-tracking/tests.ipynb#ch0000006?line=1'>2</a> df1
#
# File c:\Users\dtyq2\Desktop\repos\Wallet-tracking\venv\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\dtyq2\Desktop\repos\Wallet-tracking\venv\lib\site-packages\pandas\core\series.py:1481, in Series.reset_index(self, level, drop, name, inplace)
#    1477         return self._constructor(
#    1478             self._values.copy(), index=new_index
#    1479         ).__finalize__(self, method="reset_index")
#    1480 elif inplace:
# -> 1481     raise TypeError(
#    1482         "Cannot reset_index inplace on a Series to create a DataFrame"
#    1483     )
#    1484 else:
#    1485     if name is lib.no_default:
#    1486         # For backwards compatibility, keep columns as [0] instead of
#    1487         #  [None] when self.name is None
#
# TypeError: Cannot reset_index inplace on a Series to create a DataFrame

# %%
#ax = df1.plot.bar(x='token',y='USD',stacked=True)
df2=df.groupby(['address','token', 'contract address', 'chain'])['USD'].sum()
df3= df2.unstack('chain')
df4=df3.reset_index()
print(df4.shape)
col_to_plot = df4.columns.tolist()
df4[col_to_plot].plot(x='token',kind='bar', stacked=True)
# Out:
# (23, 6)
# <AxesSubplot:xlabel='token'>

# %%
df2=df.groupby(['address','token', 'contract address', 'chain'])['USD'].sum()
df3= df2.unstack('address')
df4=df3.reset_index()
print(df4)
col_to_plot = df4.columns.tolist()
print(col_to_plot)
df4[col_to_plot].plot(x='token',kind='bar', stacked=True)
# Out:
# address      token                            contract address         chain  \
# 0             AAVE  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9      ethereum
# 1             BUSD  0x4fabb145d64652a948d72533023f6e7a623c7c53      ethereum
# 2             COMP  0xc00e94cb662c3520282e6f5717214004a7f26888      ethereum
# 3              CRV  0xd533a949740bb3306d119cc777fa900ba034cd52      ethereum
# 4              DAI  0x6b175474e89094c44da98b954eedeac495271d0f      ethereum
# 5               DX  0x973e52691176d36453868d9d86572788d27041a9      ethereum
# 6        FTX Token  0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9      ethereum
# 7              GMX  0xfc5a1a6eb076a2c7ad06ed22c90d7e710e35ad0a  arbitrum-one
# 8             LINK  0x514910771af9ca656af840dff83e8264ecf986ca      ethereum
# 9            RADAR  0x44709a920fccf795fbc57baa433cc3dd53c44dbe      ethereum
# 10             SNX  0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f      ethereum
# 11             SPA  0xb4a3b0faf0ab53df58001804dda5bfc6a3d59008      ethereum
# 12           SUSHI  0x6b3595068778dd592e39a122f4f5a5cf09c90fe2      ethereum
# 13             TCT  0x4824a7b64e3966b0133f4f4ffb1b9d6beb75fff7      ethereum
# 14             UNI  0x1f9840a85d5af5bf1d1762f925bdaddc4201f984      ethereum
# 15            USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48      ethereum
# 16            USDT  0xdac17f958d2ee523a2206206994597c13d831ec7      ethereum
# 17             YFI  0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e      ethereum
# 18             ZKS  0xe4815ae53b124e7263f08dcdbbb757d41ed658c6      ethereum
# 19           pAVAX  0x6ca558bd3eab53da1b25ab97916dd14bf6cfee4e     avalanche
# 20            sGMX  0x908c4d94d34924765f1edc22a1dd098397c59dd4  arbitrum-one
# 21           sbGMX  0x4d268a7d4c16ceb5a606c173bd974984343fea13  arbitrum-one
# 22          sbfGMX  0xd2d1162512f927a7e282ef43a362659e4f2a728f  arbitrum-one
#
# address  0x534a0076fb7c2b1f83fa21497429ad7ad3bd7587  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               0.0
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              0.0
# 21                                              0.0
# 22                                              0.0
#
# address  0x8e04af7f7c76daa9ab429b1340e0327b5b835748
# 0                                         57.783849
# 1                                         -0.037954
# 2                                         13.356013
# 3                                        185.687569
# 4                                        -14.520657
# 5                                     801090.948606
# 6                                       2326.807026
# 7                                               NaN
# 8                                       -744.680117
# 9                                          0.000000
# 10                                        30.797536
# 11                                        58.227721
# 12                                        -0.410740
# 13                                         1.405190
# 14                                      -155.512369
# 15                                    237695.825220
# 16                                   -883811.554857
# 17                                       457.872931
# 18                                        94.260969
# 19                                         0.045205
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# ['token', 'contract address', 'chain', '0x534a0076fb7c2b1f83fa21497429ad7ad3bd7587', '0x8e04af7f7c76daa9ab429b1340e0327b5b835748']
# <AxesSubplot:xlabel='token'>
